# %%
import tensorflow

# %%
from tensorflow import keras
from sklearn.datasets import load_iris
# Out:
# C:\python\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
X = load_iris()['data']
y = load_iris()['target']
y = keras.utils.to_categorical(y)
X_train, X_test, y_train, y_test = train_test_split(X,y)
# Out:
# C:\python\lib\site-packages\sklearn\datasets\base.py:240: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   target = np.empty((n_samples,), dtype=np.int)
# ...

# %%
model = keras.models.Sequential(
    [
        keras.layers.Dense(10,activation='relu',input_shape=(4,)),
        keras.layers.Dense(100,activation='relu'),
        keras.layers.Dense(3,activation='softmax')
        
    ]
)

# %%
model.compile(optimizer='rmsprop',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(X_train,
          y_train,
         epochs=100,
         validation_data=(X_test,y_test))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 49ms/step - loss: 1.4756 - accuracy: 0.0179 - val_loss: 1.2175 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1876 - accuracy: 0.0268 - val_loss: 1.1037 - val_accuracy: 0.2632
# Epoch 3/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0807 - accuracy: 0.4018 - val_loss: 1.0676 - val_accuracy: 0.2895
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0149 - accuracy: 0.5000 - val_loss: 1.0350 - val_accuracy: 0.5000
# Epoch 5/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9676 - accuracy: 0.7143 - val_loss: 0.9828 - val_accuracy: 0.5000
# Epoch 6/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9159 - accuracy: 0.7232 - val_loss: 0.9581 - val_accuracy: 0.5000
# Epoch 7/100
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1283 - accuracy: 0.9737
# [0.12829864025115967, 0.9736841917037964]

# %%
X_test[0]
# Out:
# array([5. , 2.3, 3.3, 1. ])

# %%
import numpy as np
np.argmax(y_test[0])
# Out:
# 1

# %%
np.argmax(model.predict(X_test[[0]]))
# Out:
# 1/1 [==============================] - 0s 65ms/step
# 1

# %%
import keras.datasets

# %%
dir(keras.datasets)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'boston_housing',
#  'cifar',
#  'cifar10',
#  'cifar100',
#  'fashion_mnist',
#  'imdb',
#  'mnist',
#  'reuters']

# %%
from keras.datasets import mnist

# %%
(X_train, y_train),(X_test,y_test) = mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt

# %%
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# %%
model1 = keras.models.Sequential(
    [
        keras.layers.Flatten(input_shape=(28,28)),
        keras.layers.Dense(256,activation='relu'),
        keras.layers.Dense(128,activation='relu'),
        keras.layers.Dense(10,activation='softmax')
    ]
)

# %%
model1.compile(
    optimizer='adam',
              loss='categorical_crossentropy',
               metrics=['accuracy']
              )

# %%
model1.fit(X_train,
          y_train,
          epochs=30,
          batch_size=200,
          validation_data=(X_test,y_test))
# Out:
# Epoch 1/30
# 300/300 [==============================] - 1s 4ms/step - loss: 3.6902 - accuracy: 0.8701 - val_loss: 0.7717 - val_accuracy: 0.9190
# Epoch 2/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.4998 - accuracy: 0.9375 - val_loss: 0.5410 - val_accuracy: 0.9331
# Epoch 3/30
# 300/300 [==============================] - 1s 4ms/step - loss: 0.2637 - accuracy: 0.9573 - val_loss: 0.4232 - val_accuracy: 0.9408
# Epoch 4/30
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1868 - accuracy: 0.9645 - val_loss: 0.3672 - val_accuracy: 0.9495
# Epoch 5/30
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1354 - accuracy: 0.9718 - val_loss: 0.3694 - val_accuracy: 0.9486
# Epoch 6/30
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1097 - accuracy: 0.9765 - val_loss: 0.3138 - val_accuracy: 0.9560
# Epoch 7/30
# ...

# %%
model1.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1822 - accuracy: 0.9755
# [0.18223823606967926, 0.9754999876022339]

# %%
np.argmax(model1.predict(X_test[[7]]))
# Out:
# 1/1 [==============================] - 0s 14ms/step
# 9

# %%
plt.imshow(X_test[7])

# %%
np.argmax(y_test[7])
# Out:
# 9

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense_6 (Dense)             (None, 256)               200960
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 10)                1290
#
# ...
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2 = Sequential()
model2.add(Dense(256,activation='sigmoid',input_shape=(28*28,)))
model2.add(Dense(128,activation='relu'))
model2.add(Dense(10,activation='softmax'))

# %%
X_train1 = X_train.reshape(-1,28*28)
X_test1 = X_test.reshape(-1,28*28)

# %%
model2.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=["accuracy"])

# %%
model2.fit(X_train1,y_train,epochs=30,
           validation_data=(X_test1,y_test))
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5327 - accuracy: 0.8536 - val_loss: 0.3144 - val_accuracy: 0.9137
# Epoch 2/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2939 - accuracy: 0.9158 - val_loss: 0.2689 - val_accuracy: 0.9218
# Epoch 3/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2617 - accuracy: 0.9247 - val_loss: 0.2420 - val_accuracy: 0.9297
# Epoch 4/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2360 - accuracy: 0.9299 - val_loss: 0.2249 - val_accuracy: 0.9333
# Epoch 5/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2268 - accuracy: 0.9327 - val_loss: 0.2191 - val_accuracy: 0.9331
# Epoch 6/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2127 - accuracy: 0.9365 - val_loss: 0.2188 - val_accuracy: 0.9344
# Epoch 7/30
# ...

# %%
np.argmax(model2.predict(X_test1[[1]]))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 2

# %%
plt.imshow(X_test[1])

# %%
def step(x):
    return np.where(x>0,1,0)

# %%
x = np.linspace(-5,5,100)
plt.plot(x,step(x))

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
x = np.linspace(-5,5,100)
y = sigmoid(x)
plt.plot(x,y)
plt.plot(x,step(x))

# %%
def relu(x):
    return np.where(x<=0,0,x)

# %%
plt.plot(x,relu(x))

# %%
X = np.random.randn(100,5)

# %%
W = np.random.randn(5,10)
b = np.random.randn(10)

# %%
X_1 = np.dot(X,W)+b

# %%
sigmoid(X_1)
# Out:
# array([[1.01757973e-01, 4.45529819e-01, 1.93378665e-01, 6.31376021e-01,
#         1.02287924e-01, 5.48494595e-01, 6.26321662e-01, 3.15585393e-01,
#         5.35481262e-01, 1.68731699e-01],
#        [5.78553417e-01, 7.96527273e-01, 2.50902884e-01, 8.75092902e-02,
#         7.68920250e-01, 7.14979006e-01, 8.69732323e-01, 8.38520295e-01,
#         5.40707947e-01, 4.14164970e-01],
#        [4.73325530e-02, 6.45398899e-02, 9.91969307e-01, 9.39901666e-01,
#         2.20832472e-01, 5.46120203e-02, 4.65460579e-03, 2.28389151e-02,
#         1.79724765e-01, 7.80876567e-02],
#        [8.76777908e-01, 6.88767019e-01, 7.37857280e-01, 9.78091337e-01,
#         2.02223542e-01, 6.00637595e-01, 5.87717723e-02, 1.29285658e-01,
#         8.63307008e-01, 5.60321588e-01],
#        [2.26877177e-01, 1.24338937e-01, 3.98753475e-01, 5.52875109e-01,
#         1.17463208e-01, 2.75009566e-01, 5.20320559e-01, 2.01761220e-01,
#         4.63837623e-01, 7.48000777e-02],
# ...

# %%
from keras import activations

# %%
from keras.datasets import fashion_mnist

# %%
(X_train, y_train),(X_test,y_test) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense
from keras.activations import ReLU, LeakyReLU,Softmax
from keras.optimizers import Adam

# %%
dir(keras.layers)
# Out:
# ['AbstractRNNCell',
#  'Activation',
#  'ActivityRegularization',
#  'Add',
#  'AdditiveAttention',
#  'AlphaDropout',
#  'Attention',
#  'Average',
#  'AveragePooling1D',
#  'AveragePooling2D',
#  'AveragePooling3D',
#  'AvgPool1D',
#  'AvgPool2D',
#  'AvgPool3D',
#  'BatchNormalization',
#  'BatchNormalizationV1',
#  'BatchNormalizationV2',
#  'Bidirectional',
#  'CategoryEncoding',
#  'CenterCrop',
#  'ClassMethod',
#  'Concatenate',
#  'Conv1D',
#  'Conv1DTranspose',
#  'Conv2D',
#  'Conv2DTranspose',
#  'Conv3D',
#  'Conv3DTranspose',
#  'ConvLSTM1D',
#  'ConvLSTM2D',
#  'ConvLSTM3D',
#  'Convolution1D',
#  'Convolution1DTranspose',
#  'Convolution2D',
#  'Convolution2DTranspose',
#  'Convolution3D',
#  'Convolution3DTranspose',
#  'Cropping1D',
#  'Cropping2D',
#  'Cropping3D',
#  'CuDNNGRU',
#  'CuDNNLSTM',
#  'Dense',
#  'DepthwiseConv1D',
#  'DepthwiseConv2D',
#  'DeviceWrapper',
#  'Discretization',
#  'Dot',
#  'Dropout',
#  'DropoutWrapper',
#  'ELU',
#  'EinsumDense',
# ...

# %%
model = Sequential(
    [
        Flatten(input_shape=(28,28)),
        Dense(256,activation=ReLU()),
        Dense(128,activation=ReLU()),
        keras.layers.BatchNormalization(),
        Dense(64,activation=ReLU()),
        Dense(10,activation=Softmax()), 
    ]
)

# %%
model.compile(optimizer=Adam(lr=2e-6),
             loss=keras.losses.CategoricalCrossentropy(),
             metrics=['accuracy'])

# %%
hist = model.fit(X_train,
         y_train,
         epochs=10,
         batch_size=200,
         validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 300/300 [==============================] - 2s 5ms/step - loss: 2.5315 - accuracy: 0.1614 - val_loss: 2.2924 - val_accuracy: 0.2578
# Epoch 2/10
# 300/300 [==============================] - 1s 4ms/step - loss: 2.1039 - accuracy: 0.3244 - val_loss: 1.9149 - val_accuracy: 0.4068
# Epoch 3/10
# 300/300 [==============================] - 1s 4ms/step - loss: 1.8015 - accuracy: 0.4449 - val_loss: 1.6722 - val_accuracy: 0.4950
# Epoch 4/10
# 300/300 [==============================] - 1s 4ms/step - loss: 1.5881 - accuracy: 0.5210 - val_loss: 1.5003 - val_accuracy: 0.5579
# Epoch 5/10
# 300/300 [==============================] - 1s 4ms/step - loss: 1.4403 - accuracy: 0.5753 - val_loss: 1.3767 - val_accuracy: 0.5999
# Epoch 6/10
# 300/300 [==============================] - 1s 3ms/step - loss: 1.3287 - accuracy: 0.6130 - val_loss: 1.2852 - val_accuracy: 0.6282
# Epoch 7/10
# ...

# %%
plt.plot(np.arange(1,11),hist.history['accuracy'])
